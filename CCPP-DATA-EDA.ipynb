# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"E:\DataScience-data\combined_cycle_power_plant.csv",delimiter=';')

# %%
df.shape
# Out:
# (9568, 5)

# %%
df.head()
# Out:
#    temperature  exhaust_vacuum  ambient_pressure  relative_humidity  \
# 0         9.59           38.56           1017.01              60.10
# 1        12.04           42.34           1019.72              94.67
# 2        13.87           45.08           1024.42              81.69
# 3        13.72           54.30           1017.89              79.08
# 4        15.14           49.64           1023.78              75.00
#
#    energy_output
# 0         481.30
# 1         465.36
# 2         465.48
# 3         467.05
# 4         463.58

# %%
a=df.columns.tolist()
print(a)
# !!pip install seaborn
# Out:
# ['temperature', 'exhaust_vacuum', 'ambient_pressure', 'relative_humidity', 'energy_output']

# %%
for i in a:
    print(i)
    print(df[i].describe())
    sns.histplot(x=i,bins=10,data=df)
    plt.show()
# Out:
# temperature
# count    9568.000000
# mean       19.651231
# std         7.452473
# min         1.810000
# 25%        13.510000
# 50%        20.345000
# 75%        25.720000
# max        37.110000
# Name: temperature, dtype: float64
# exhaust_vacuum
# count    9568.000000
# mean       54.305804
# std        12.707893
# min        25.360000
# 25%        41.740000
# 50%        52.080000
# 75%        66.540000
# max        81.560000
# Name: exhaust_vacuum, dtype: float64
# ambient_pressure
# count    9568.000000
# mean     1013.259078
# std         5.938784
# min       992.890000
# 25%      1009.100000
# 50%      1012.940000
# 75%      1017.260000
# max      1033.300000
# Name: ambient_pressure, dtype: float64
# relative_humidity
# count    9568.000000
# mean       73.308978
# std        14.600269
# min        25.560000
# 25%        63.327500
# 50%        74.975000
# 75%        84.830000
# max       100.160000
# Name: relative_humidity, dtype: float64
# energy_output
# ...

# %%
for i in a:
    sns.scatterplot(x=i,y='energy_output',data=df,color='y')
    plt.show()

# %%
for i in a:
    plt.scatter(x=df[i],y=df['energy_output'],color='y')
    plt.show()

# %%
sns.pairplot(df)
plt.show()
